# %%
# Standard library imports
import glob
import os
import re
import shutil
import getpass
from pathlib import Path
from urllib.parse import urlparse

# Third-party imports
import pandas as pd
import requests
from bs4 import BeautifulSoup, NavigableString

# LangChain imports
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTe

# %%
# Prompt for OpenAI API key with password masking
print("Please enter your OpenAI API key:")
openai_api_key = getpass.getpass("API Key: ")

# Set as environment variable
os.environ["OPENAI_API_KEY"] = openai_api_key

# Verify it was set (show only first/last few characters for security)
if openai_api_key:
    masked_key = f"{openai_api_key[:7]}...{openai_api_key[-4:]}"
    print(f"✓ API key set successfully: {masked_key}")
else:
    print("✗ No API key entered")
# Out:
# Please enter your OpenAI API key:
# ✓ API key set successfully: sk-proj...jXgA

# %%
# Delete the existing database
db_path = Path('./chroma-db_latin2')
if db_path.exists():
    shutil.rmtree(db_path)
    print(f"✓ Deleted existing database at {db_path}")


# # Initialize embeddings
embeddings = OpenAIEmbeddings(model='text-embedding-3-large')


# Initialize Chroma vector store

vector_store = Chroma(
    collection_name="HTML_samples_latin",
    embedding_function=embeddings,
    persist_directory='./chroma-db_latin3'
)

# vector_store, embeddings = initialize_vector_store()

# Configure text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,
    chunk_overlap=300,
    length_function=len,
    is_separator_regex=False
)
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
# Standard library imports
import glob
import os
import re
import shutil
import getpass
from pathlib import Path
from urllib.parse import urlparse

# Third-party imports
import pandas as pd
import requests
from bs4 import BeautifulSoup, NavigableString

# LangChain imports
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTe

# %%
# run this on all files in the source directory:  this is just to get the text, not the vector db
tei_dir = Path("latin_sources")
for html_path in tei_dir.glob("*.xml"):
    with html_path.open("r", encoding="utf-8") as handle:
        html_content = handle.read()    

        results = extract_pages_and_text(html_content, html_path)

# %%
# just to check one result

results[0]
# Out:
# {'PageNumber': 'page 1',
#  'PageText': 'Incipit tractatus IX. Caput I. De coniunctionibus vocum, quid sint, et quot. Coniunctio in musica est dispositio sive ordinatio sonorum sive vocum ad invicem in syllabis et dictionibus. Coniunctiones autem in musica 16. esse dicuntur, scilicet semitonium, tonus, semiditonus, ditonus, diatessaron, diapente imperfectum, tritonus, diapente, hexade minus, hexade maius, heptade minus, (supplevi heptade maius, diapason imperfectum) diapason perfectum, diapason diapente, et bis diapason. Harum autem omnium coniunctionum aliae dicuntur coniunctiones et syllabae, aliae coniunctiones et species, et aliae coniunctiones tantum. Quae autem dicuntur coniunctiones et syllabae, sunt quatuor, scilicet semitonium, tonus, semiditonus et ditonus, quarum exempla sunt haec:',
#  'Filename': 'MARLU9.xml',
#  'Title': 'Lucidarium, tractatus nonus',
#  'Author': 'Marchetus de Padua',
#  'Date': '14th',
#  'Source': 'chtmlMARLU9.xml'}

# %%
# get metaddata df
tei_dir = Path("latin_sources")
all_metadata = []
for html_path in tei_dir.glob("*.xml"):
    with html_path.open("r", encoding="utf-8") as handle:
        html_content = handle.read()    
        metadata = extract_metadata(BeautifulSoup(html_content, 'xml'), html_path)  
        all_metadata.append(metadata)   
metadata_df = pd.DataFrame(all_metadata)
metadata_df.to_csv("latin_tei_metadata.csv", index=False)

# %%
def process_xml_files(xml_dir='latin_sources'):
    """Process all TEI XML files in the specified directory."""
    xml_files = glob.glob(os.path.join(xml_dir, '*.xml'))
    
    if not xml_files:
        print(f"No TEI XML files found in {xml_dir}")
        return
    
    total_chunks = 0
    total_pages = 0
    
    for filepath in xml_files:
        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                xml_content = f.read()

            metadata = extract_metadata(BeautifulSoup(xml_content, 'xml'), Path(filepath)) 
            print(f"Metadata for {filepath}: {metadata}")
            
            # Parse XML
            pages = extract_pages_and_text(xml_content, Path(filepath))
            
            
            if not pages:
                print(f"Warning: No pages found in {filepath}")
                continue
            
            file_chunks = 0
            
            # Process each page separately
            for page in pages:
                # Create metadata for this page, combining document and page metadata
                page_metadata = {
                    "title": page['Title'],
                    "author": page['Author'],
                    "date": page['Date'],
                    "source": page['Source'],
                    "page_number": page['PageNumber']
                }
                
                # Split page text into chunks
                chunks = text_splitter.create_documents(
                    texts=[page['PageText']],
                    metadatas=[page_metadata]
                )
                
                # Add chunks to vector store
                vector_store.add_documents(documents=chunks)
                
                file_chunks += len(chunks)
                total_chunks += len(chunks)
            
            total_pages += len(pages)
            print(f'✓ {os.path.basename(filepath)}')
            print(f'  Title: {page["Title"][:80]}...' if len(page["Title"]) > 80 else f'  Title: {page["Title"]}')
            print(f'  Author: {page["Author"]}')
            print(f'  Date: {page["Date"]}')
            print(f'  Source: {page["Source"]}')
            
            print(f'  Pages: {len(pages)} | Chunks: {file_chunks}')
            
        except Exception as e:
            print(f"✗ Error processing {filepath}: {str(e)}")
            import traceback
            traceback.print_exc()
            continue
    
    print(f'\n{"="*50}')
    print(f'ChromaDB Processing Complete')
    print(f'{"="*50}')
    print(f'Files processed: {len(xml_files)}')
    print(f'Total pages: {total_pages}')
    print(f'Total chunks: {total_chunks}')

# %%
process_xml_files(xml_dir='latin_sources')
# Out:
# Metadata for latin_sources/MARLU4.xml: {'Filename': 'MARLU4.xml', 'Title': 'Lucidarium, tractatus quartus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU4.xml'}
# ✓ MARLU4.xml
#   Title: Lucidarium, tractatus quartus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU4.xml
#   Pages: 3 | Chunks: 4
# Metadata for latin_sources/MARLU5.xml: {'Filename': 'MARLU5.xml', 'Title': 'Lucidarium, tractatus quintus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU5.xml'}
# ✓ MARLU5.xml
#   Title: Lucidarium, tractatus quintus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU5.xml
#   Pages: 4 | Chunks: 5
# Metadata for latin_sources/MARLU7.xml: {'Filename': 'MARLU7.xml', 'Title': 'Lucidarium, tractatus septimus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU7.xml'}
# ✓ MARLU7.xml
#   Title: Lucidarium, tractatus septimus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU7.xml
#   Pages: 2 | Chunks: 2
# Metadata for latin_sources/MARLU6.xml: {'Filename': 'MARLU6.xml', 'Title': 'Lucidarium, tractatus sextus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU6.xml'}
# ✓ MARLU6.xml
#   Title: Lucidarium, tractatus sextus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU6.xml
#   Pages: 5 | Chunks: 8
# Metadata for latin_sources/MARLU2.xml: {'Filename': 'MARLU2.xml', 'Title': 'Lucidarium, tractatus secundus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU2.xml'}
# ✓ MARLU2.xml
#   Title: Lucidarium, tractatus secundus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU2.xml
#   Pages: 7 | Chunks: 13
# Metadata for latin_sources/MARLU3.xml: {'Filename': 'MARLU3.xml', 'Title': 'Lucidarium, tractatus tertius', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU3.xml'}
# ✓ MARLU3.xml
#   Title: Lucidarium, tractatus tertius
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU3.xml
#   Pages: 3 | Chunks: 4
# Metadata for latin_sources/MARLU1.xml: {'Filename': 'MARLU1.xml', 'Title': 'Lucidarium, tractatus primus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU1.xml'}
# ✓ MARLU1.xml
#   Title: Lucidarium, tractatus primus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU1.xml
#   Pages: 7 | Chunks: 12
# Metadata for latin_sources/MARLU11.xml: {'Filename': 'MARLU11.xml', 'Title': 'Lucidarium, tractatus undecimus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU11.xml'}
# ✓ MARLU11.xml
#   Title: Lucidarium, tractatus undecimus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU11.xml
#   Pages: 17 | Chunks: 23
# Metadata for latin_sources/MARLU10.xml: {'Filename': 'MARLU10.xml', 'Title': 'Lucidarium, tractatus decimus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU10.xml'}
# ✓ MARLU10.xml
#   Title: Lucidarium, tractatus decimus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU10.xml
#   Pages: 1 | Chunks: 1
# Metadata for latin_sources/MARLU12.xml: {'Filename': 'MARLU12.xml', 'Title': 'Lucidarium, tractatus duodecimus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU12.xml'}
# ✓ MARLU12.xml
#   Title: Lucidarium, tractatus duodecimus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU12.xml
#   Pages: 3 | Chunks: 4
# Metadata for latin_sources/MARLU13.xml: {'Filename': 'MARLU13.xml', 'Title': 'Lucidarium, tractatus decimustertius', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU13.xml'}
# ✓ MARLU13.xml
#   Title: Lucidarium, tractatus decimustertius
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU13.xml
#   Pages: 1 | Chunks: 1
# Metadata for latin_sources/BURMUS2.xml: {'Filename': 'BURMUS2.xml', 'Title': 'Musices opusculum, tractatus secundus', 'Author': 'Burtius, Nicolaus', 'Date': '15th', 'Source': 'chtmlBURMUS2.xml'}
# ✓ BURMUS2.xml
#   Title: Musices opusculum, tractatus secundus
#   Author: Burtius, Nicolaus
#   Date: 15th
#   Source: chtmlBURMUS2.xml
#   Pages: 13 | Chunks: 13
# Metadata for latin_sources/MARLU16.xml: {'Filename': 'MARLU16.xml', 'Title': 'Lucidarium, tractatus decimussextus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU16.xml'}
# ✓ MARLU16.xml
#   Title: Lucidarium, tractatus decimussextus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU16.xml
#   Pages: 1 | Chunks: 1
# Metadata for latin_sources/BURMUS3.xml: {'Filename': 'BURMUS3.xml', 'Title': 'Musices opusculum, tractatus tertius', 'Author': 'Burtius, Nicolaus', 'Date': '15th', 'Source': 'chtmlBURMUS3.xml'}
# ✓ BURMUS3.xml
#   Title: Musices opusculum, tractatus tertius
#   Author: Burtius, Nicolaus
#   Date: 15th
#   Source: chtmlBURMUS3.xml
#   Pages: 55 | Chunks: 55
# Metadata for latin_sources/BURMUS1.xml: {'Filename': 'BURMUS1.xml', 'Title': 'Musices opusculum, tractatus primus', 'Author': 'Burtius, Nicolaus', 'Date': '15th', 'Source': 'chtmlBURMUS1.xml'}
# ✓ BURMUS1.xml
#   Title: Musices opusculum, tractatus primus
#   Author: Burtius, Nicolaus
#   Date: 15th
#   Source: chtmlBURMUS1.xml
#   Pages: 67 | Chunks: 67
# Metadata for latin_sources/MARLU14.xml: {'Filename': 'MARLU14.xml', 'Title': 'Lucidarium, tractatus decimusquartus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU14.xml'}
# ✓ MARLU14.xml
#   Title: Lucidarium, tractatus decimusquartus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU14.xml
#   Pages: 1 | Chunks: 1
# Metadata for latin_sources/MARLU15.xml: {'Filename': 'MARLU15.xml', 'Title': 'Lucidarium, tractatus decimusquintus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU15.xml'}
# ✓ MARLU15.xml
#   Title: Lucidarium, tractatus decimusquintus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU15.xml
#   Pages: 1 | Chunks: 1
# Metadata for latin_sources/ANO4MUS.xml: {'Filename': 'ANO4MUS.xml', 'Title': '[Musica]', 'Author': 'Anonymous 4', 'Date': '13th', 'Source': 'chtmlANO4MUS.xml'}
# ✓ ANO4MUS.xml
#   Title: [Musica]
#   Author: Anonymous 4
#   Date: 13th
#   Source: chtmlANO4MUS.xml
#   Pages: 68 | Chunks: 103
# Metadata for latin_sources/BOEMUS5.xml: {'Filename': 'BOEMUS5.xml', 'Title': 'De institutione musica, liber quintus', 'Author': 'Boethius, Anicius Manlius Severinus', 'Date': '6th-8th', 'Source': 'chtmlBOEMUS5.xml'}
# ✓ BOEMUS5.xml
#   Title: De institutione musica, liber quintus
#   Author: Boethius, Anicius Manlius Severinus
#   Date: 6th-8th
#   Source: chtmlBOEMUS5.xml
#   Pages: 23 | Chunks: 23
# Metadata for latin_sources/BOEMUS4.xml: {'Filename': 'BOEMUS4.xml', 'Title': 'De institutione musica, liber quartus', 'Author': 'Boethius, Anicius Manlius Severinus', 'Date': '6th-8th', 'Source': 'chtmlBOEMUS4.xml'}
# ✓ BOEMUS4.xml
#   Title: De institutione musica, liber quartus
#   Author: Boethius, Anicius Manlius Severinus
#   Date: 6th-8th
#   Source: chtmlBOEMUS4.xml
#   Pages: 51 | Chunks: 54
# Metadata for latin_sources/BOEMUS3.xml: {'Filename': 'BOEMUS3.xml', 'Title': 'De institutione musica, liber tertius', 'Author': 'Boethius, Anicius Manlius Severinus', 'Date': '6th-8th', 'Source': 'chtmlBOEMUS3.xml'}
# ✓ BOEMUS3.xml
#   Title: De institutione musica, liber tertius
#   Author: Boethius, Anicius Manlius Severinus
#   Date: 6th-8th
#   Source: chtmlBOEMUS3.xml
#   Pages: 34 | Chunks: 34
# Metadata for latin_sources/BOEMUS2.xml: {'Filename': 'BOEMUS2.xml', 'Title': 'De institutione musica, liber secundus', 'Author': 'Boethius, Anicius Manlius Severinus', 'Date': '6th-8th', 'Source': 'chtmlBOEMUS2.xml'}
# ✓ BOEMUS2.xml
#   Title: De institutione musica, liber secundus
#   Author: Boethius, Anicius Manlius Severinus
#   Date: 6th-8th
#   Source: chtmlBOEMUS2.xml
#   Pages: 43 | Chunks: 43
# Metadata for latin_sources/MARLU8.xml: {'Filename': 'MARLU8.xml', 'Title': 'Lucidarium, tractatus octavus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU8.xml'}
# ✓ MARLU8.xml
#   Title: Lucidarium, tractatus octavus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU8.xml
#   Pages: 5 | Chunks: 7
# Metadata for latin_sources/BOEMUS1.xml: {'Filename': 'BOEMUS1.xml', 'Title': 'De institutione musica, liber primus', 'Author': 'Boethius, Anicius Manlius Severinus', 'Date': '6th-8th', 'Source': 'chtmlBOEMUS1.xml'}
# ✓ BOEMUS1.xml
#   Title: De institutione musica, liber primus
#   Author: Boethius, Anicius Manlius Severinus
#   Date: 6th-8th
#   Source: chtmlBOEMUS1.xml
#   Pages: 32 | Chunks: 32
# Metadata for latin_sources/MARLU9.xml: {'Filename': 'MARLU9.xml', 'Title': 'Lucidarium, tractatus nonus', 'Author': 'Marchetus de Padua', 'Date': '14th', 'Source': 'chtmlMARLU9.xml'}
# ✓ MARLU9.xml
#   Title: Lucidarium, tractatus nonus
#   Author: Marchetus de Padua
#   Date: 14th
#   Source: chtmlMARLU9.xml
#   Pages: 9 | Chunks: 10
#
# ==================================================
# ChromaDB Processing Complete
# ==================================================
# Files processed: 25
# Total pages: 456
# Total chunks: 521

# %%
# for checking page and character counts


pages = results
        # Calculate lengths of all PageText entries
page_lengths = [len(page['PageText']) for page in pages]
avg_length = sum(page_lengths) / len(page_lengths)
    
# print(f"\n{filename}:")
print(f"  Total pages: {len(pages)}")
print(f"  Average PageText length: {avg_length:.2f} characters")
print(f"  Min length: {min(page_lengths)} characters")
print(f"  Max length: {max(page_lengths)} characters")
# Out:
#   Total pages: 32
#   Average PageText length: 1337.62 characters
#   Min length: 215 characters
#   Max length: 1782 characters

# %%
# another check

for page in pages:
    if len(page['PageText']) > 3000:
        print(f"long page found: {page['PageNumber']} with length {len(page['PageText'])}")

# %%
all_docs = vector_store.get()
authors = set()
if 'Metadata' in all_docs:
    for metadata in all_docs['Metadata']:
        if metadata and 'Author' in metadata:
            authors.add(metadata['Author'])

# %%
authors
# Out:
# set()

# %%
all_docs
# Out:
# {'ids': ['575b5998-f2f0-43d0-846b-76f41b94af70',
#   'c10aa9b0-9d5e-4508-87c0-fcbe11646244',
#   '10ee31fe-7134-439c-83dc-152dbb537dc4',
#   '6c40befb-aec0-4fc6-8169-db1f33780916',
#   '9ba4896a-b9d3-43dd-8262-5735d0cf70a6',
#   'b379e73d-c9be-463f-a53d-99c60699f4cf',
#   '9edf8ec4-cc72-4cfc-8e38-b555a86aa825',
#   'ba9383b0-f23c-4d65-bd44-5c8194959530',
#   'e8dcca28-e5d1-4321-8eab-b65ef99226d7',
#   '8f580275-a2de-4a3c-9611-1dcebd3753e6',
#   '9b814c3b-d86f-4f85-8c97-68aeac9ba79d',
#   '500a5d96-fd3d-47f6-b809-9c9265762cff',
#   '7659cc8b-7855-4ce1-af07-01b6e1d04405',
#   'cb3ba85d-6609-49a9-bdea-cc52b57e3e00',
#   'cd9a6c32-4d7f-47cf-9ece-98af7291da78',
#   '76632a59-b947-4643-9e5b-0fdffcfa7c36',
#   'd54f75eb-b019-4434-ab90-412200fe090e',
#   '3e8054f1-068f-4139-bb07-32339f86fef2',
#   '3e32c668-e8b2-4355-ad8a-ce00181ffbdf',
#   '7283ed6e-8d53-4dca-a494-21af2a4a98b7',
#   '453d32ba-2c95-481e-8939-fd1627fcbe6e',
#   '1b185540-7b4a-47f6-840f-662204ec0ed3',
#   'bb9fffad-549d-424c-af1a-dcbbf5d65f93',
#   '8d7d7de2-c770-4b79-9673-10d640620a36',
#   'ca6b5b3c-1178-4ac4-af53-e3e711dd2d5a',
#   '019467d5-38d7-47f5-aff0-e8e6fbf08758',
#   '4c869fd8-f219-433e-9e99-488b74760a0c',
#   'ef38f45f-3af0-40aa-abed-663b0ceab47e',
#   '4a96a63c-38f0-4fd4-b7c3-2866c30eb56a',
#   '3bfc0fac-6d4c-41f7-8031-680d0c4404cc',
#   '12f6bf70-e541-4c7e-99b6-9d9729712280',
#   '90b8a382-0fed-417a-8b19-f651e3d95657',
#   '03f8b78b-0fab-4937-b8dc-67c45d108b10',
#   '7fb0022f-20cc-499f-b753-8b06780f8de1',
#   '0ca4898e-4d2c-4d60-974d-f4d17a4ef0af',
#   'be1b1841-9133-41fc-ac01-85902a834d02',
#   '64bbfb4e-2c72-4485-9ab0-ac1fa605c0b1',
#   'c836877c-4e48-4892-881a-1dca024be6d0',
#   'dba1e16f-e3f5-47b7-a61f-7a85de04675d',
#   '3dd1a971-f890-4327-87d4-401d65a866e6',
#   '503a6def-e9e2-471f-b47a-5e2868395573',
#   '5cd8dad4-82e1-43ed-abec-684c4fd3565e',
#   'cc01cd35-4010-4e08-bd44-e1db40ff68fe',
#   '49418bc5-5e3a-4a93-82e8-9a99b0b9bee9',
#   '119121f8-1098-4e4f-a7d1-ffaa6fa4572e',
#   '6b25eb3f-bae9-457e-bd78-1be260a28ac9',
#   '47baa6df-3952-4859-a53c-c6f2328df26b',
#   '7bab5ecc-ea72-44eb-8fcd-04352b3fd2d7',
#   '98aa8613-592b-472d-a2b9-47b6250edb5f',
#   '0ede088b-40be-4099-95f7-eb5dc1e1a1e9',
#   'b2b73e8f-fc61-4fd4-813d-85470115f7a8',
#   '1f29b260-e28f-4ae9-a317-08b4766b795c',
#   '6a6905ed-94c1-4e40-ba6f-b3dee6dd179e',
#   'fcdf0d40-0abf-4209-8d50-cf58d7ff92d4',
#   '05f160df-476c-4adc-96cf-8df405c808f1',
#   'f13dddc2-3418-4096-8ba1-3b8c42f9be9a',
#   '584f57ed-6e5b-4c72-b1ad-b9fe81beaaae',
#   'b610f697-a894-4a02-8db4-e17a891ebe4f',
#   'f82d4eb0-a769-4b77-8f31-d19d2ee8bd1f',
#   '90315657-8d6e-46a0-b07e-9643de65a9bc',
#   'd6847729-3229-47f4-a033-378c2305544e',
#   'b0aaef94-1f53-447e-86d1-2f541f9c6b4f',
#   '419af8f0-7835-41e5-b84c-ab8d9b8dcbd9',
#   '23322faf-32d8-460e-a64c-d3c0b8887527',
#   '2e87ee20-b1d6-4fe6-bb2a-dec42e76de4b',
#   'e354e9ad-b55a-4ec8-bcbb-100d2a3f1151',
#   'f18ca642-a8f1-4794-a1a8-bc1794f7bd0c',
#   '7eb0dd5e-4943-4c3b-8422-44ec6be0e86d',
#   'f5fb00aa-389b-4ada-b59b-4f617775adba',
#   '211444c1-337a-4ba5-a59f-74f23a8cc2b9',
#   '55c55313-4394-4774-bbda-a0c63661f892',
#   '7bde51fa-5326-4d3d-947d-e9fd173a111d',
#   '36bab5b9-518a-4283-8565-2f0398bdbc66',
#   '250492ad-0c45-4ac1-84d2-bc735e79d2e4',
#   '60235bac-7bcb-4999-8f3f-30031045aab7',
#   '1158f36e-f907-45ee-b13f-5eeb4048393f',
#   '2cde9298-a30d-43ad-836b-12d7f3426cb6',
#   'a4d1f95a-84b4-488c-8210-68a0228e3f6a',
#   'f53c5f50-6379-45f1-92cb-4935645c01a2',
#   '7114d98b-7215-478f-8cf3-2a945570a0e9',
#   'efcdeac5-32ac-4eb8-b45a-968bb8e7ae4c',
#   '16b887df-3dad-40cf-9bbc-1dacfd7ce49a',
#   '8eb9bdfe-1e65-47cd-bfc7-435d70c41e65',
#   'c2b221ab-3383-43de-9cb9-8e490579e140',
#   '2acfae32-076f-4f67-b47a-7bb957fbd239',
#   'a379a900-e3e0-453e-a207-8e198d4fd507',
#   '31cfe33b-488a-4dc7-b8e1-05e8167ccf93',
#   'e7b908b5-00ad-44ef-89f9-371373d0efed',
#   '69780ee3-c945-4b44-bab9-686f8a2d8911',
#   '0f986188-b2c3-4c73-9d08-ef32c70c3417',
#   '3b044a36-7689-464e-8a22-6ea26f85ca4a',
#   '997a2f8f-17fe-4d38-ba59-91a2e48b2d5d',
#   'b781cbff-36c3-429b-b768-1c9eb9306a90',
#   '4ecdbbbf-eef4-47d1-85c2-da6810dbfa8c',
#   '3aaa319e-bee0-4bc5-8d9a-24279cb98360',
#   'aa558b15-0e69-4a4d-a1e7-ab4d68874cc8',
#   '25a0c11e-ddd4-4325-b099-cb6fc4de6437',
#   'fe7d1017-b311-4dd1-a79e-a9db1f46e6ee',
#   'dbe22fc2-1992-46d2-bb52-c1b39fbe0d43',
#   '243c7f3c-30b7-43ee-951c-251cea25d334',
#   'c394fcbb-7dba-45c2-aa7a-ec285db94f47',
#   '54e35147-6a48-4ab6-a434-ba5b965132de',
#   '6b4238b8-b2d7-464f-b802-690b633f7ec1',
#   'be3cbc1a-d537-4017-920c-304ad6419793',
#   '38625c1e-6615-4638-ae99-62c577bc1a97',
#   'bcf614ef-708d-45e5-bd50-e2fad969b285',
#   '577e350b-18dc-4b0e-a19e-53b629cc1410',
#   'f4719e6a-7166-478a-883f-1e2314581f6f',
#   '79079820-e3ce-4baf-8aab-93dc37f6f7d3',
#   '7bbc1bf5-c353-433b-83d9-243312c3ee38',
#   '8dc68c51-7d69-484a-b429-8ea62ba1978f',
#   'c6254a58-73d2-4923-a1df-21dec854c9e9',
#   'ec4b4f75-3372-4075-a0fe-a320d3286be6',
#   '8d3f7bb9-1387-4939-a7a3-55258c113599',
#   '78c6967b-0ec9-4192-9684-bac50ac9eaa6',
#   'c21916b1-e945-4516-8a62-3815808f48ec',
#   'dfbacce9-097f-4318-8068-81db6f2acf19',
#   '3ce91b9c-e3bf-46ee-92f5-c9631626bf42',
#   '3b2bd9d2-6245-4464-a349-d528ea186783',
#   '9a949be0-ebd9-4232-8d14-259df75fb526',
#   '5ebdf53c-7bde-43af-abc0-e07a5419a5ad',
#   '0956fed5-7c39-4c30-9933-b800e0b7d0a6',
#   '0eba5304-3b46-4ea0-9241-c58121abd228',
#   'f45fd7de-2fab-42f3-95f0-c537fce4b15b',
#   '41a89598-36f1-4f09-adde-d9656c4180c9',
#   '79c0f01c-0b26-49d5-8020-41abb2ab2c42',
#   '058266db-db01-453e-88f4-d8fd2312b15b',
#   '3c0b79d3-4425-4e49-ab30-d6ba3fc7a60a',
#   '915c9940-2981-4501-b345-5c00dcb2d963',
#   'af1c60c5-0330-4684-9ce2-d9e51f7e1cec',
#   'bf215064-c4fd-4c49-ae6a-fb05b15dcc83',
#   '6f52d1d2-8831-44b4-bafa-8fb47e1d5861',
#   '4ad35475-247b-406b-bca0-b1f3a9439288',
#   'b6bbfe71-9866-4b33-897e-9a03ebacaf04',
#   'b321835f-4f45-4fb1-8d5f-f3258b7e7dca',
#   'e9ff1831-3009-49a3-b446-aa23e6d068ee',
#   '94513d82-a1c1-4205-85ac-1211c77799e0',
#   '72426fb7-8dec-438b-aff4-c24f08b89da2',
#   '5297a721-f2cc-4360-b154-a6d561aa6297',
#   'f0e17386-ad05-4f0a-8e38-4d01baac6644',
#   'bbdd80a1-84f9-40ae-b580-d5fb896ed290',
#   '608f233e-a965-46c7-9811-2d8aab763287',
#   '33565faf-fbba-443c-9774-62cfb1be86d8',
#   '5572ca59-7d35-46bd-a06c-441815239d1f',
#   '67ce9eaf-7436-4444-acd9-02b97548e36a',
#   'f75b0b12-f888-4672-aa11-fd9b4b5438b8',
#   'a363d63d-f3cf-4190-acc4-443c27a3229d',
#   '35d64fd1-57e6-424a-8709-102b9bcfa2b1',
#   '599cb1c2-e040-4cc2-96ad-08478727f4aa',
#   '3f2aece5-c00f-433c-b360-70aae5fbb127',
#   'bd5f316f-7a10-4d63-8527-f2be3337288a',
#   'a98ce5ad-3351-412a-8ac2-139e9f38df65',
#   'dff01658-6427-46cf-9429-f0093ef9f3e3',
#   'bf3686e9-ea2c-4a50-a75d-4821b16b1634',
#   'dd6ba07f-916d-4c15-ac51-3f737990f016',
#   '384538ac-c322-418e-b9bd-4d787a51c086',
#   '1fa65a3a-3fe8-4dcb-8dd9-69cf34ffda83',
#   '115bd6d0-6417-4f7f-83d6-fef6cf6e0e9b',
#   '21f56b2e-31a8-4a82-9b87-40a3125f0edb',
#   '72e0acda-e7a5-4c4d-8f85-136bf6b13126',
#   '2a4e1242-28f6-4b15-9cba-f8aad845b347',
#   '4f4270a2-399a-4b51-837f-4633b4bc50b1',
#   'ded1b5fa-e10a-44fc-a547-b7d90f2c942f',
#   '89ac8c79-f28f-41d1-9b2f-72bc847f8383',
#   'd1e87f58-4090-4214-a680-1a36ad4d4281',
#   '2d49424d-5534-42ac-aa57-ec06188fb60b',
#   '5e98ec67-63de-4edf-8c1d-4af6fc362a39',
#   'c643b846-ac68-43f6-bffa-7c2c5996eb0d',
#   'c0730f06-9b74-4c99-bf3e-906e83669e93',
#   'a48057e9-e115-4bec-acb7-6eed7ff75a1e',
#   'f2b3eab5-9a44-4ccb-804f-7a8ed3282d1b',
#   '62452879-a2fe-42b2-a9ef-930b1d721615',
#   '64887f8a-c8ff-4904-aef5-b27c21158a20',
#   'c40e08a6-3bf2-4b18-ad88-f60eb06d6c6d',
#   'd509e852-d355-4a9b-9b26-95745e7baf5d',
#   'bf8e8cff-55bb-41c8-b4d6-86b8775aa8a0',
#   '3299234f-9a79-4ff4-b7ae-a3022c3fea05',
#   '8622c58f-ff28-4915-adc1-6b0777e6b01f',
#   '90ece976-3c80-4c33-b003-0808432ef264',
#   '06006be3-daf7-4a6b-8c0a-9cbcce64d044',
#   '2b429e23-1aee-4fea-87a5-d611d8b3a84e',
#   '93ecacaf-b520-4b54-a89d-b9b68023fd4d',
#   '4e8ba3d9-c82f-4e82-bd95-5ccb59995ad7',
#   'b4dcbdc3-75c2-497c-929e-1cd5bf2c5750',
#   'ee35574e-d54a-4859-a831-8d4a0b61d61b',
#   '9fd29d7a-2137-4924-bfdc-20db5a9f4f7d',
#   'c99ec0d9-f7a8-4d6e-baab-33b0d4f12bc2',
#   'eff7bb6a-65d1-4332-8dd9-4509d66a7669',
#   '87f3b1a0-702e-4805-9527-d3df7fe6c593',
#   '04549882-ce1b-40f2-9cbe-87716cb85ce1',
#   'b29ba85b-e6dc-4035-9a08-74bfa5f876cb',
#   'c5f59e9d-68c6-4c51-b9ad-e2e45ee5582f',
#   '34f5ac9a-a830-48a3-81ad-15dfefe1fcc8',
#   'e5bb2d9b-8c71-49d6-abed-8256bf050946',
#   '15dcc175-6fde-4f12-ae71-b41db612dd74',
#   '9cb20b6f-ceea-462b-9473-7e3af1bfe74e',
#   '6153e874-b0d3-4a5b-906e-5c8dac261ffd',
#   'b91add7a-0504-407b-8f2d-7ef40028a91a',
#   '5d6a6bff-504d-4cb2-afcc-020ec167aa38',
#   '8dab49c3-18ec-41dc-a43c-eb181fa69c39',
#   '9bf4abfa-3926-48cc-9da2-c12ecfd9cfc4',
#   'd7829e11-61c0-4cdb-a9a2-0636e2993e15',
#   '0a1e48c4-3a1a-42b9-8786-0da183cca78a',
#   '4bb164fd-e393-4317-99f1-4f7973e527ab',
#   '1f5d06ef-333c-4729-8ba3-0bef22027c46',
#   '611bb0d6-fe20-469d-bc96-a914e9f0f027',
#   'a22cf20b-a927-4933-abfc-532f68e0645c',
#   'b3c82c0e-f7f6-4afc-a25e-f1c9c17b88d3',
#   'd642ca82-7157-469b-8330-9ba98320ff41',
#   'fc89e2ee-ee2d-4ce9-b2da-a25f16ba455d',
#   '1f586a6c-695e-4054-a47c-0a65b01fb1aa',
#   '648ca597-66ae-4102-b8e3-4463b3e396f2',
#   'e8aed288-ee5e-4b0d-b647-fa05b6917fc8',
#   '975eeba4-5ebc-437b-8167-ba40b39bd464'],
#  'embeddings': None,
#  'documents': ['Marcheti de Padua Musica, seu Lucidarium in arte musicae planae ex manuscripta.',
#   'et regit sonos: humana voce productos: naturalibus cooperantibus instrumentis: ars est spectabilis ac scientia perfecta: modulationis constans ex tribus scilicet sonis: verbis et numeris. Poete preterea non necant hanc ipsam metricam esse: qua probabili ratione: diuersorum pedum mensuram cognoscunt. Ut dactili: iambi: et tribaci: et huiusmodi cum temporum attendant terminationem. De artifici alibus restat videre. Instrumenta vero artificialia aliqua sunt delectationem incitantia. Alia vero quae animositatem: iram: furiam quoque et huiusmodi inducunt. Delectationem incitantia sunt videlicet: organa: monocordia: psalterij: cythare: lyre: atque tibicinum concentus: quibus etiam romani vsi sunt in capitolio. Ut apud Ualerium de institutionibus antiquis capitulo tibicinum collegium. tum ad placandorum deorum iram: tum etiam ad summam eorum venerationem. Quod etiam religio nostra: trinum deum ac vnicum his cantibus: organisque: assiduis laudibus deprecando: placare non desinit. Tibicinum namque triumphus marti attributus est. Apollini cythara: musis tibie: ceteraque eiusdem generis attributa sunt. Instrumenta vero animositatem: iram: et furiam incitantia: sunt tube: cornua: timpana: et huiusmodi strepitum excitantia: atque sonantia: quorum clangor quantum fuerit vehementior: tantum bellatorum animus ad certamen fortior. Unde Lacedemoniorum exercitus: his musicis accensus est modis. Hinc proculdubio romanam gloriam ceteris',
# ...
#    'date': '13th'},
#   {'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'page_number': 'page 17'},
#   {'author': 'Anonymous 4',
#    'page_number': 'page 17',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'title': '[Musica]'},
#   {'title': '[Musica]',
#    'page_number': 'page 18',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th'},
#   {'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'page_number': 'page 18',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml'},
#   {'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'page_number': 'page 19'},
#   {'date': '13th',
#    'page_number': 'page 20',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml'},
#   {'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'page_number': 'page 20'},
#   {'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'page_number': 'page 21'},
#   {'page_number': 'page 21',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'author': 'Anonymous 4'},
#   {'title': '[Musica]',
#    'date': '13th',
#    'author': 'Anonymous 4',
#    'page_number': 'page 22',
#    'source': 'chtmlANO4MUS.xml'},
#   {'author': 'Anonymous 4',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 23',
#    'title': '[Musica]'},
#   {'author': 'Anonymous 4',
#    'date': '13th',
#    'title': '[Musica]',
#    'page_number': 'page 24',
#    'source': 'chtmlANO4MUS.xml'},
#   {'author': 'Anonymous 4',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]',
#    'page_number': 'page 25'},
#   {'author': 'Anonymous 4',
#    'date': '13th',
#    'page_number': 'page 25',
#    'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]'},
#   {'date': '13th',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]',
#    'page_number': 'page 26'},
#   {'page_number': 'page 27',
#    'date': '13th',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]'},
#   {'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'page_number': 'page 27',
#    'date': '13th'},
#   {'page_number': 'page 28',
#    'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml'},
#   {'title': '[Musica]',
#    'page_number': 'page 28',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'date': '13th'},
#   {'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'page_number': 'page 29',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml'},
#   {'author': 'Anonymous 4',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 29',
#    'title': '[Musica]'},
#   {'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 30',
#    'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'date': '13th'},
#   {'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'page_number': 'page 30',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th'},
#   {'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 31',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'date': '13th'},
#   {'page_number': 'page 32',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'author': 'Anonymous 4',
#    'title': '[Musica]'},
#   {'date': '13th',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 32'},
#   {'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]',
#    'page_number': 'page 33',
#    'date': '13th',
#    'author': 'Anonymous 4'},
#   {'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'date': '13th',
#    'page_number': 'page 34',
#    'source': 'chtmlANO4MUS.xml'},
#   {'title': '[Musica]',
#    'page_number': 'page 34',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'date': '13th'},
#   {'title': '[Musica]',
#    'page_number': 'page 35',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'date': '13th'},
#   {'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 36',
#    'author': 'Anonymous 4',
#    'title': '[Musica]'},
#   {'date': '13th',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 37',
#    'author': 'Anonymous 4'},
#   {'page_number': 'page 37',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]'},
#   {'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'page_number': 'page 38',
#    'title': '[Musica]'},
#   {'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'page_number': 'page 39',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th'},
#   {'date': '13th',
#    'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'page_number': 'page 39',
#    'source': 'chtmlANO4MUS.xml'},
#   {'page_number': 'page 40',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml'},
#   {'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 40',
#    'date': '13th'},
#   {'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 41',
#    'date': '13th'},
#   {'page_number': 'page 41',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml'},
#   {'page_number': 'page 42',
#    'date': '13th',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml'},
#   {'page_number': 'page 43',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'author': 'Anonymous 4',
#    'title': '[Musica]'},
#   {'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 44',
#    'author': 'Anonymous 4',
#    'title': '[Musica]'},
#   {'author': 'Anonymous 4',
#    'date': '13th',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 45'},
#   {'page_number': 'page 46',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'title': '[Musica]'},
#   {'page_number': 'page 47',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th'},
#   {'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'page_number': 'page 47',
#    'title': '[Musica]'},
#   {'date': '13th',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'page_number': 'page 48',
#    'source': 'chtmlANO4MUS.xml'},
#   {'author': 'Anonymous 4',
#    'page_number': 'page 49',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'title': '[Musica]'},
#   {'page_number': 'page 49',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'title': '[Musica]'},
#   {'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 50',
#    'title': '[Musica]',
#    'date': '13th',
#    'author': 'Anonymous 4'},
#   {'page_number': 'page 51',
#    'date': '13th',
#    'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml'},
#   {'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 52',
#    'date': '13th'},
#   {'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 53',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'title': '[Musica]'},
#   {'title': '[Musica]',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 54',
#    'author': 'Anonymous 4'},
#   {'page_number': 'page 55',
#    'date': '13th',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4'},
#   {'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 55',
#    'author': 'Anonymous 4',
#    'date': '13th'},
#   {'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 56',
#    'date': '13th',
#    'author': 'Anonymous 4'},
#   {'title': '[Musica]',
#    'page_number': 'page 57',
#    'date': '13th',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml'},
#   {'author': 'Anonymous 4',
#    'page_number': 'page 58',
#    'date': '13th',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml'},
#   {'date': '13th',
#    'author': 'Anonymous 4',
#    'page_number': 'page 59',
#    'source': 'chtmlANO4MUS.xml',
#    'title': '[Musica]'},
#   {'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 59',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'title': '[Musica]'},
#   {'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'page_number': 'page 60'},
#   {'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 61',
#    'title': '[Musica]',
#    'date': '13th',
#    'author': 'Anonymous 4'},
#   {'title': '[Musica]',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'page_number': 'page 61',
#    'author': 'Anonymous 4'},
#   {'title': '[Musica]',
#    'page_number': 'page 62',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th'},
#   {'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'date': '13th',
#    'page_number': 'page 62'},
#   {'date': '13th',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4',
#    'page_number': 'page 63'},
#   {'title': '[Musica]',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'page_number': 'page 64'},
#   {'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'page_number': 'page 64',
#    'author': 'Anonymous 4'},
#   {'date': '13th',
#    'author': 'Anonymous 4',
#    'title': '[Musica]',
#    'page_number': 'page 65',
#    'source': 'chtmlANO4MUS.xml'},
#   {'page_number': 'page 66',
#    'author': 'Anonymous 4',
#    'source': 'chtmlANO4MUS.xml',
#    'date': '13th',
#    'title': '[Musica]'},
#   {'page_number': 'page 67',
#    'title': '[Musica]',
#    'date': '13th',
#    'source': 'chtmlANO4MUS.xml',
#    'author': 'Anonymous 4'},
#   {'author': 'Anonymous 4',
#    'page_number': 'page 68',
#    'date': '13th',
#    'title': '[Musica]',
#    'source': 'chtmlANO4MUS.xml'},
#   {'source': 'chtmlBOEMUS1.xml',
#    'page_number': 'page 1',
#    'title': 'De institutione musica, liber primus',
#    'date': '6th-8th',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'date': '6th-8th',
#    'title': 'De institutione musica, liber primus',
#    'page_number': 'page 2',
#    'source': 'chtmlBOEMUS1.xml',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'page_number': 'page 3',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'title': 'De institutione musica, liber primus',
#    'date': '6th-8th',
#    'source': 'chtmlBOEMUS1.xml'},
#   {'source': 'chtmlBOEMUS1.xml',
#    'page_number': 'page 4',
#    'date': '6th-8th',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'author': 'Boethius, Anicius Manlius Severinus',
#    'page_number': 'page 5',
#    'source': 'chtmlBOEMUS1.xml',
#    'date': '6th-8th',
#    'title': 'De institutione musica, liber primus'},
#   {'title': 'De institutione musica, liber primus',
#    'page_number': 'page 6',
#    'date': '6th-8th',
#    'source': 'chtmlBOEMUS1.xml',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'date': '6th-8th',
#    'source': 'chtmlBOEMUS1.xml',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'page_number': 'page 7'},
#   {'source': 'chtmlBOEMUS1.xml',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'date': '6th-8th',
#    'page_number': 'page 8'},
#   {'source': 'chtmlBOEMUS1.xml',
#    'date': '6th-8th',
#    'page_number': 'page 9',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'page_number': 'page 10',
#    'title': 'De institutione musica, liber primus',
#    'source': 'chtmlBOEMUS1.xml',
#    'date': '6th-8th',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'date': '6th-8th',
#    'page_number': 'page 11',
#    'title': 'De institutione musica, liber primus',
#    'source': 'chtmlBOEMUS1.xml',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'page_number': 'page 12',
#    'title': 'De institutione musica, liber primus',
#    'source': 'chtmlBOEMUS1.xml',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'date': '6th-8th'},
#   {'date': '6th-8th',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'source': 'chtmlBOEMUS1.xml',
#    'page_number': 'page 13',
#    'title': 'De institutione musica, liber primus'},
#   {'source': 'chtmlBOEMUS1.xml',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'page_number': 'page 14',
#    'date': '6th-8th',
#    'title': 'De institutione musica, liber primus'},
#   {'page_number': 'page 15',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'date': '6th-8th',
#    'source': 'chtmlBOEMUS1.xml'},
#   {'source': 'chtmlBOEMUS1.xml',
#    'page_number': 'page 16',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'date': '6th-8th'},
#   {'date': '6th-8th',
#    'page_number': 'page 17',
#    'source': 'chtmlBOEMUS1.xml',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'date': '6th-8th',
#    'source': 'chtmlBOEMUS1.xml',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'page_number': 'page 18',
#    'title': 'De institutione musica, liber primus'},
#   {'page_number': 'page 19',
#    'date': '6th-8th',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'source': 'chtmlBOEMUS1.xml',
#    'title': 'De institutione musica, liber primus'},
#   {'page_number': 'page 20',
#    'source': 'chtmlBOEMUS1.xml',
#    'date': '6th-8th',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'title': 'De institutione musica, liber primus'},
#   {'source': 'chtmlBOEMUS1.xml',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'page_number': 'page 21',
#    'date': '6th-8th'},
#   {'date': '6th-8th',
#    'title': 'De institutione musica, liber primus',
#    'source': 'chtmlBOEMUS1.xml',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'page_number': 'page 22'},
#   {'source': 'chtmlBOEMUS1.xml',
#    'date': '6th-8th',
#    'page_number': 'page 23',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus'},
#   {'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'page_number': 'page 24',
#    'source': 'chtmlBOEMUS1.xml',
#    'date': '6th-8th'},
#   {'page_number': 'page 25',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'source': 'chtmlBOEMUS1.xml',
#    'date': '6th-8th'},
#   {'title': 'De institutione musica, liber primus',
#    'source': 'chtmlBOEMUS1.xml',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'date': '6th-8th',
#    'page_number': 'page 26'},
#   {'date': '6th-8th',
#    'title': 'De institutione musica, liber primus',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'source': 'chtmlBOEMUS1.xml',
#    'page_number': 'page 27'},
#   {'date': '6th-8th',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'title': 'De institutione musica, liber primus',
#    'page_number': 'page 28',
#    'source': 'chtmlBOEMUS1.xml'},
#   {'date': '6th-8th',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'title': 'De institutione musica, liber primus',
#    'page_number': 'page 29',
#    'source': 'chtmlBOEMUS1.xml'},
#   {'date': '6th-8th',
#    'source': 'chtmlBOEMUS1.xml',
#    'page_number': 'page 30',
#    'author': 'Boethius, Anicius Manlius Severinus',
#    'title': 'De institutione musica, liber primus'},
#   {'author': 'Boethius, Anicius Manlius Severinus',
#    'source': 'chtmlBOEMUS1.xml',
#    'page_number': 'page 31',
#    'date': '6th-8th',
#    'title': 'De institutione musica, liber primus'},
#   {'page_number': 'page 32',
#    'title': 'De institutione musica, liber primus',
#    'source': 'chtmlBOEMUS1.xml',
#    'date': '6th-8th',
#    'author': 'Boethius, Anicius Manlius Severinus'}]}
